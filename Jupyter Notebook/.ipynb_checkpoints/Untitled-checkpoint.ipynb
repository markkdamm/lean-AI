# %%
import pandas as pd
import numpy as np
import sys

np.set_printoptions(threshold=sys.maxsize)

# %%
user = pd.read_json('../userdata/user.json')
del user['id']
user
# Out:
#       Gender  Age    Height  Weight  family history with overweight   FAVC  \
# 0     female   21  1.620000      64                            True  False
# 1     female   21  1.520000      56                            True  False
# 2       male   23  1.800000      77                            True  False
# 3       male   27  1.800000      87                           False  False
# 4       male   22  1.780000      90                           False  False
# ...      ...  ...       ...     ...                             ...    ...
# 2106  female   21  1.710730     131                            True   True
# 2107  female   22  1.748584     134                            True   True
# 2108  female   23  1.752206     134                            True   True
# 2109  female   24  1.739450     133                            True   True
# 2110  female   24  1.738836     133                            True   True
#
# ...

# %%
user.describe(include='bool')
# Out:
#        family history with overweight  FAVC  SMOKE    SCC
# count                            2111  2111   2111   2111
# unique                              2     2      2      2
# top                              True  True  False  False
# freq                             1726  1866   2067   2015

# %%
user.NObeyesdad
# Out:
# 0             normal_weight
# 1             normal_weight
# 2             normal_weight
# 3        overweight_level_i
# 4       overweight_level_ii
#                ...
# 2106       obesity_type_iii
# 2107       obesity_type_iii
# 2108       obesity_type_iii
# 2109       obesity_type_iii
# 2110       obesity_type_iii
# Name: NObeyesdad, Length: 2111, dtype: object

# %%
weight = user['NObeyesdad'].tolist()
weight
# Out:
# ['normal_weight',
#  'normal_weight',
#  'normal_weight',
#  'overweight_level_i',
#  'overweight_level_ii',
#  'normal_weight',
#  'normal_weight',
#  'normal_weight',
#  'normal_weight',
#  'normal_weight',
#  'obesity_type_i',
#  'overweight_level_ii',
#  'normal_weight',
#  'obesity_type_i',
#  'normal_weight',
#  'normal_weight',
#  'overweight_level_ii',
#  'obesity_type_i',
#  'overweight_level_ii',
#  'overweight_level_i',
#  'overweight_level_ii',
#  'obesity_type_i',
#  'normal_weight',
#  'obesity_type_i',
#  'normal_weight',
#  'normal_weight',
#  'normal_weight',
#  'normal_weight',
#  'normal_weight',
#  'normal_weight',
#  'overweight_level_i',
#  'overweight_level_ii',
#  'normal_weight',
#  'overweight_level_ii',
#  'normal_weight',
#  'overweight_level_ii',
#  'normal_weight',
#  'normal_weight',
#  'normal_weight',
#  'overweight_level_ii',
#  'overweight_level_i',
#  'normal_weight',
#  'normal_weight',
#  'normal_weight',
#  'normal_weight',
# ...

# %%
n=0

obese= np.empty([2111,1], dtype=bool)

for x in weight:
    if weight[n] == 'normal_weight':
        obese[n] = False
    else:
        obese[n] = True
    n += 1
    
obese
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [ True],
#        [ True],
#        [ True]])

# %%
user.insert(18,'Obese',obese)
user
# Out:
#       Gender  Age    Height  Weight  family history with overweight   FAVC  \
# 0     female   21  1.620000      64                            True  False
# 1     female   21  1.520000      56                            True  False
# 2       male   23  1.800000      77                            True  False
# 3       male   27  1.800000      87                           False  False
# 4       male   22  1.780000      90                           False  False
# ...      ...  ...       ...     ...                             ...    ...
# 2106  female   21  1.710730     131                            True   True
# 2107  female   22  1.748584     134                            True   True
# 2108  female   23  1.752206     134                            True   True
# 2109  female   24  1.739450     133                            True   True
# 2110  female   24  1.738836     133                            True   True
#
# ...

# %%
user_clean_mixed = user.drop(['Height','Weight','family history with overweight'], axis=1)
user_clean_mixed 
male = user_clean_mixed[(user_clean_mixed == 'male').any(axis=1)]
male
# Out:
#      Gender  Age   FAVC  FCVC  NCP  CAEC  SMOKE  CH2O    SCC     FAF     TUE  \
# 2      male   23  False     2    3     1  False     1  False  2 to 4  3 to 5
# 3      male   27  False     3    3     1  False     1  False  2 to 4  0 to 2
# 4      male   22  False     2    1     1  False     1  False       0  0 to 2
# 5      male   29   True     2    3     1  False     1  False       0  0 to 2
# 7      male   22  False     2    3     1  False     1  False  4 to 5  0 to 2
# ...     ...  ...    ...   ...  ...   ...    ...   ...    ...     ...     ...
# 1794   male   31   True     3    2     1  False     0  False  1 to 2  3 to 5
# 1795   male   20   True     3    1     1  False     1  False       0  3 to 5
# 1796   male   21   True     3    1     1  False     0  False       0  3 to 5
# 1797   male   26   True     3    1     1  False     0  False       0  3 to 5
# 1798   male   27   True     3    1     1  False     0  False       0  3 to 5
#
# ...

# %%
female = user_clean_mixed[(user_clean_mixed == 'female').any(axis=1)]
female
# Out:
#       Gender  Age   FAVC  FCVC  NCP  CAEC  SMOKE  CH2O    SCC     FAF     TUE  \
# 0     female   21  False     2    3     1  False     1  False       0  3 to 5
# 1     female   21  False     3    3     1   True     2   True  4 to 5  0 to 2
# 6     female   23   True     3    3     1  False     1  False  1 to 2  0 to 2
# 11    female   21   True     2    3     2  False     1   True  2 to 4  3 to 5
# 15    female   22  False     3    3     3  False     1   True  2 to 4  3 to 5
# ...      ...  ...    ...   ...  ...   ...    ...   ...    ...     ...     ...
# 2106  female   21   True     3    3     1  False     1  False  2 to 4  3 to 5
# 2107  female   22   True     3    3     1  False     1  False  1 to 2  3 to 5
# 2108  female   23   True     3    3     1  False     1  False  1 to 2  3 to 5
# 2109  female   24   True     3    3     1  False     2  False  1 to 2  3 to 5
# 2110  female   24   True     3    3     1  False     2  False  1 to 2  3 to 5
#
# ...
