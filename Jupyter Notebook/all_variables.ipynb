# %%
import pandas as pd
import numpy as np
import sys

np.set_printoptions(threshold=sys.maxsize)

# %%
user = pd.read_json('../userdata/user.json')
del user['id']
del user['BMI']
del user['Weight']
user
# Out:
#       Gender  Age    Height  family history with overweight  FAVC  FCVC  NCP  \
# 0          0   21  1.620000                               1     0     2    3
# 1          0   21  1.520000                               1     0     3    3
# 2          1   23  1.800000                               1     0     2    3
# 3          1   27  1.800000                               0     0     3    3
# 4          1   22  1.780000                               0     0     2    1
# ...      ...  ...       ...                             ...   ...   ...  ...
# 2106       0   21  1.710730                               1     1     3    3
# 2107       0   22  1.748584                               1     1     3    3
# 2108       0   23  1.752206                               1     1     3    3
# 2109       0   24  1.739450                               1     1     3    3
# 2110       0   24  1.738836                               1     1     3    3
#
# ...

# %%
user.describe()
# Out:
#             Gender          Age       Height  family history with overweight  \
# count  2111.000000  2111.000000  2111.000000                     2111.000000
# mean      0.505921    24.315964     1.701677                        0.817622
# std       0.500083     6.357078     0.093305                        0.386247
# min       0.000000    14.000000     1.450000                        0.000000
# 25%       0.000000    20.000000     1.630000                        1.000000
# 50%       1.000000    23.000000     1.700499                        1.000000
# 75%       1.000000    26.000000     1.768464                        1.000000
# max       1.000000    61.000000     1.980000                        1.000000
#
#               FAVC         FCVC          NCP         CAEC        SMOKE  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean      0.883941     2.423496     2.687826     1.140692     0.020843
# ...

# %%
user.NObeyesdad[(user == '0').any(axis=1)]
# Out:
# Series([], Name: NObeyesdad, dtype: int64)
